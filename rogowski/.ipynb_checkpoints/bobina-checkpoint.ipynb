# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np

# %%
headers = ['t', 'ch1', 'ch2']
df = pd.read_csv ('caloventor.csv',header=1, sep=';', decimal=',', names=headers)

# %%
df.describe()
# Out:
#             t        ch1      ch2
# count   20001      20001    20001
# unique  20001        974      144
# top     t / s  0,0606061  0,00808
# freq        1        665      629

# %%
df.head()
# Out:
#          t       ch1      ch2
# 0  0.00001 -0.121616  0.00704
# 1  0.00002 -0.121616  0.00636
# 2  0.00003 -0.121212  0.00684
# 3  0.00004 -0.121414  0.00700
# 4  0.00005 -0.121818  0.00648

# %%
df.set_index('t').plot()
# Out:
# <AxesSubplot:xlabel='t'>

# %%
df['ch1x10'] = df['ch1']*10

# %%
df.head()
# Out:
#          t       ch1      ch2   ch1x10
# 0  0.00001 -0.121616  0.00704 -1.21616
# 1  0.00002 -0.121616  0.00636 -1.21616
# 2  0.00003 -0.121212  0.00684 -1.21212
# 3  0.00004 -0.121414  0.00700 -1.21414
# 4  0.00005 -0.121818  0.00648 -1.21818

# %%
from scipy import integrate

# %%
np.trapz(df["t"][0:2], x=df["ch2"][0:2])
# Out:
# -1.0200000000000002e-08

# %%
df["t"][0:1]
# Out:
# 0    0.00001
# Name: t, dtype: float64
